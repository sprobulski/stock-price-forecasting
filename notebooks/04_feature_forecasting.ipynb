# %% [markdown]
# # Feature Forecasting for Predictive Modeling
#
# ## Forecasting Framework
#
# This notebook implements a sophisticated feature forecasting system using gradient boosting methodology to predict future values of time-varying features. The approach recognizes that effective stock price prediction requires not only historical feature values but also forecasted feature values for the prediction horizon.
#
# ## Feature Classification and Forecasting Strategy
#
# Our methodology categorizes features based on their temporal characteristics and predictability:
#
# **Predictable Features**: These include technical indicators, market indices, interest rates, and other variables that exhibit daily variation and can be modeled using historical patterns. These features are forecasted using XGBoost models trained on lagged feature values.
#
# **Forward-Filled Features**: Economic indicators such as CPI, PPI, and employment data are released monthly with reporting lags. These features are forward-filled from their last known values, as they represent structural economic conditions that change gradually.
#
# **Temporal Structure**: The forecasting models utilize multiple lag periods to capture both short-term momentum and longer-term trend patterns in the feature evolution.
#
# The system generates two critical datasets: historical validation data for model verification and future prediction data for forward-looking analysis. This dual approach enables robust validation of forecasting accuracy while providing the forward-looking features necessary for stock price prediction.

# %%
# Initialize feature forecasting pipeline
import sys
sys.path.append('../src')
from feature_forecasting import (
    load_and_prepare_data, create_lagged_features,
    train_feature_models, create_historical_validation_data, 
    create_future_prediction_data, diagnostic_analysis
)

# Define forecasting parameters
ticker = input("Enter the ticker symbol to analyze (or press Enter to use AAPL): ").upper() or "AAPL"
prediction_horizon = 5
lag_periods = [1, 2, 3]

print(f"Feature forecasting analysis for {ticker}")
print(f"Prediction horizon: {prediction_horizon} days")
print(f"Lag structure: {lag_periods} periods")

# Load and categorize features for forecasting
df, forward_filled_features, predictable_features, all_features = load_and_prepare_data(ticker)
print(f"Dataset loaded: {df.shape}")
print(f"Predictable features: {len(predictable_features)} (require forecasting)")
print(f"Forward-filled features: {len(forward_filled_features)} (structural/economic)")

# Create temporal lag structure for predictive modeling
df_lagged = create_lagged_features(df, predictable_features, lag_periods)
print(f"Lagged feature matrix: {df_lagged.shape}")
print("Temporal dependencies captured through multi-period lag structure")
# Out:
# Analyzing data for MSFT
# 🚀 Feature Forecasting Step-by-Step for MSFT
# ============================================================
# 📊 Step 1: Loading and preparing data...
# Data shape: (451, 34)
# Date range: 2023-09-01 00:00:00 to 2025-06-20 00:00:00
#
# Columns: ['Date', 'CPI', 'Close', 'Consumer_Sentiment', 'Dow_Jones', 'Fed_Funds_Rate', 'High', 'Housing_Starts', 'Industrial_Production', 'Low', 'NASDAQ', 'Open', 'PPI', 'S&P_500', 'Sector_Technology', 'Treasury_10Y', 'Treasury_3M', 'Unemployment_Rate', 'VIX', 'Volume', 'SMA_20', 'SMA_50', 'EMA_20', 'ATR', 'Bollinger_Upper', 'Bollinger_Lower', 'RSI', 'OBV', 'CPI_YoY_Change', 'PPI_YoY_Change', 'Yield_Curve_Spread', 'Fed_10Y_Spread', 'Treasury_10Y_DoD', 'Treasury_3M_DoD']
# Forward-filled features (13): ['Fed_Funds_Rate', 'CPI', 'PPI', 'Unemployment_Rate', 'Industrial_Production', 'Consumer_Sentiment', 'Housing_Starts', 'CPI_YoY_Change', 'PPI_YoY_Change', 'Yield_Curve_Spread', 'Fed_10Y_Spread', 'Treasury_10Y_DoD', 'Treasury_3M_DoD']
#
# Predictable features (19): ['Dow_Jones', 'High', 'Low', 'NASDAQ', 'Open', 'S&P_500', 'Sector_Technology', 'Treasury_10Y', 'Treasury_3M', 'VIX', 'Volume', 'SMA_20', 'SMA_50', 'EMA_20', 'ATR', 'Bollinger_Upper', 'Bollinger_Lower', 'RSI', 'OBV']
#
# Total features: 32, Categorized: 32
#    • Data shape: (451, 34)
#    • Predictable features: 19
#    • Forward-filled features: 13
#    • All features: 32
# 🔄 Step 2: Creating lagged features...
#    • Lagged data shape: (448, 77)
# Sample lagged feature names: ['Dow_Jones_lag1', 'Dow_Jones_lag2', 'Dow_Jones_lag3', 'High_lag1', 'High_lag2', 'High_lag3', 'Low_lag1', 'Low_lag2', 'Low_lag3', 'NASDAQ_lag1']

# %%
# Configure model training parameters
n_iter = 50
cv_folds = 20
param_grid = {
    'max_depth': [2, 3, 4],  
    'min_child_weight': [5, 10, 15],  
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9],
    'reg_alpha': [0.1, 0.5, 1, 2, 3],  
    'reg_lambda': [0.1, 0.5, 1, 2, 5], 
    'gamma': [0.4, 0.5],
    'n_estimators': [50, 100, 150, 200]
}

# Train individual forecasting models for each predictable feature
models, scalers, performance, lagged_feature_names = train_feature_models(
    df_lagged, predictable_features, lag_periods,
    n_iter=n_iter, cv_folds=cv_folds, param_grid=param_grid
)

# Evaluate overall forecasting performance
avg_smape = sum(perf['test_smape'] for perf in performance.values()) / len(performance)
print(f"Feature forecasting models trained: {len(models)}")
print(f"Average forecasting accuracy (sMAPE): {avg_smape:.4f}")
print("Individual XGBoost models optimized for each predictable feature")
# Out:
# Step 2: Training feature models...
# Training on 358 samples
# Testing on 90 samples
# Using 57 lagged features
#
# Training model for Dow_Jones (1/19)...
#   Train RMSE: 144.058576, Test RMSE: 867.034357
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: EXCELLENT
#
# Training model for High (2/19)...
#   Train RMSE: 2.617526, Test RMSE: 12.617349
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: VERY GOOD
#
# Training model for Low (3/19)...
#   Train RMSE: 1.803694, Test RMSE: 15.414154
#   Train sMAPE: 0.00%, Test sMAPE: 0.02% 🟢
#   Performance: VERY GOOD
#
# Training model for NASDAQ (4/19)...
#   Train RMSE: 21.902998, Test RMSE: 123.456737
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: EXCELLENT
#
# Training model for Open (5/19)...
#   Train RMSE: 1.506580, Test RMSE: 12.092204
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: VERY GOOD
#
# Training model for S&P_500 (6/19)...
#   Train RMSE: 1.510113, Test RMSE: 5.712762
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: VERY GOOD
#
# Training model for Sector_Technology (7/19)...
#   Train RMSE: 1.192681, Test RMSE: 7.024987
#   Train sMAPE: 0.02%, Test sMAPE: 0.08% 🟡
#   Performance: GOOD
#
# Training model for Treasury_10Y (8/19)...
#   Train RMSE: 0.022996, Test RMSE: 0.077679
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: EXCELLENT
#
# Training model for Treasury_3M (9/19)...
#   Train RMSE: 0.009542, Test RMSE: 0.086995
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: EXCELLENT
#
# Training model for VIX (10/19)...
#   Train RMSE: 101.991861, Test RMSE: 460.324565
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: EXCELLENT
#
# Training model for Volume (11/19)...
#   Train RMSE: 6018606.176758, Test RMSE: 8166535.712305
#   Train sMAPE: 0.09%, Test sMAPE: 0.12% 🟡
#   Performance: ACCEPTABLE
#
# Training model for SMA_20 (12/19)...
#   Train RMSE: 0.345831, Test RMSE: 6.185086
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: EXCELLENT
#
# Training model for SMA_50 (13/19)...
#   Train RMSE: 0.311037, Test RMSE: 9.610534
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: EXCELLENT
#
# Training model for EMA_20 (14/19)...
#   Train RMSE: 0.337405, Test RMSE: 5.750367
#   Train sMAPE: 0.00%, Test sMAPE: 0.00% 🟢
#   Performance: EXCELLENT
#
# Training model for ATR (15/19)...
#   Train RMSE: 0.211749, Test RMSE: 1.902665
#   Train sMAPE: 0.01%, Test sMAPE: 0.05% 🟡
#   Performance: GOOD
#
# Training model for Bollinger_Upper (16/19)...
#   Train RMSE: 0.322651, Test RMSE: 8.501478
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: EXCELLENT
#
# Training model for Bollinger_Lower (17/19)...
#   Train RMSE: 0.371273, Test RMSE: 14.436991
#   Train sMAPE: 0.00%, Test sMAPE: 0.01% 🟢
#   Performance: VERY GOOD
#
# Training model for RSI (18/19)...
#   Train RMSE: 3.987541, Test RMSE: 6.017038
#   Train sMAPE: 0.03%, Test sMAPE: 0.05% 🟢
#   Performance: VERY GOOD
#
# Training model for OBV (19/19)...
#   Train RMSE: 13623452.759647, Test RMSE: 58059127.167112
#   Train sMAPE: 0.02%, Test sMAPE: 0.04% 🟢
#   Performance: VERY GOOD
#    • Models trained: 19
#    • Average sMAPE: 0.0248

# %%
# Generate historical validation dataset with forecasted features
validation_data = create_historical_validation_data(
    df, df_lagged, models, scalers,
    predictable_features, forward_filled_features, lag_periods
)
print(f"Historical validation dataset created: {len(validation_data)} observations")
print("Contains forecasted feature values for recent historical periods")
print("Enables validation of forecasting accuracy against known outcomes")
# Out:
# Step 4: Creating historical validation data...
# Test set: indices 358 to 448 (size: 90)
#
# ============================================================
# GENERATING MULTIPLE VALIDATION DATASETS
# ============================================================
#
# 1. LAST 5 DAYS VALIDATION:
#    Historical start index: 440 (out of 448 total)
#    Predicting features for last 5 historical days
# Predicting day 1/5...
# Predicting day 2/5...
# Predicting day 3/5...
# Predicting day 4/5...
# Predicting day 5/5...
#    Shape: (5, 22)
#    Date range: 2025-06-13 00:00:00 to 2025-06-20 00:00:00
#
# 2. FIRST 5 DAYS OF TEST SET:
#    Start index: 355 (predicting from test index 358)
# Predicting day 1/5...
# Predicting day 2/5...
# Predicting day 3/5...
# Predicting day 4/5...
# Predicting day 5/5...
#    Shape: (5, 22)
#    Date range: 2025-02-11 00:00:00 to 2025-02-18 00:00:00
# Predicting day 1/5...
# Predicting day 2/5...
# Predicting day 3/5...
# Predicting day 4/5...
# Predicting day 5/5...
# Generated Test_Days_15-19: (5, 22)
# Predicting day 1/5...
# Predicting day 2/5...
# Predicting day 3/5...
# Predicting day 4/5...
# Predicting day 5/5...
# Generated Test_Days_30-34: (5, 22)
# Predicting day 1/5...
# Predicting day 2/5...
# Predicting day 3/5...
# Predicting day 4/5...
# Predicting day 5/5...
# Generated Test_Days_45-49: (5, 22)
# Predicting day 1/5...
# Predicting day 2/5...
# Predicting day 3/5...
# Predicting day 4/5...
# Predicting day 5/5...
# Generated Test_Days_60-64: (5, 22)
# Predicting day 1/5...
# Predicting day 2/5...
# Predicting day 3/5...
# Predicting day 4/5...
# Predicting day 5/5...
# Generated Test_Days_75-79: (5, 22)
#
# TOTAL VALIDATION SAMPLES: 35
# ============================================================
# ADDING FORWARD-FILLED FEATURES TO VALIDATION DATASETS
# Forward-filled features to add: ['Fed_Funds_Rate', 'CPI', 'PPI', 'Unemployment_Rate', 'Industrial_Production', 'Consumer_Sentiment', 'Housing_Starts', 'CPI_YoY_Change', 'PPI_YoY_Change', 'Yield_Curve_Spread', 'Fed_10Y_Spread', 'Treasury_10Y_DoD', 'Treasury_3M_DoD']
#
# Adding to Validation dataset...
#    Updated shape: (35, 35)
#
# FINAL FEATURE COUNT:
#    • Total features per dataset: 32
#    • Predictable features: 19
#    • Forward-filled features: 13
#    • Expected total: 35
#    • Validation samples: 35

# %%
# Generate future prediction dataset for forward-looking analysis
future_data = create_future_prediction_data(
    df, df_lagged, models, scalers,
    predictable_features, forward_filled_features, lag_periods
)
print(f"Future prediction dataset created: {len(future_data)} forecast periods")
print("Contains forecasted feature values for forward-looking price prediction")
print("Feature forecasting pipeline completed successfully")

# %%
# Step 5: Diagnostic Analysis
print("Step 5: Diagnostic Analysis")
diagnostic_analysis(validation_data, df, predictable_features)
print("=" * 80)
print("Diagnostic analysis complete")
print("=" * 80)
# Out:
# Step 5: Diagnostic Analysis
# 📊 COMPARISON DATASET:
#    • Total comparison samples: 35
#    • Validation periods: 7
#    • Date range: 2025-02-11 00:00:00 to 2025-06-20 00:00:00
#    • Features to compare: 19
# 🔍 DIAGNOSTIC ANALYSIS: MODEL PREDICTION ISSUES
# ================================================================================
# 🎯 ANALYZING TEMPORAL PREDICTION PATTERNS:
# ------------------------------------------------------------
#
# 📊 HIGH ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred= 417.2 | Actual= 409.2 | Diff=  -8.0 | Error= -2.0% 🟢 GOOD
#   Last_5_Days              : Pred= 453.0 | Actual= 480.6 | Diff= +27.6 | Error= +5.8% 🟡 MODERATE
#   Test_Days_15-19          : Pred= 402.4 | Actual= 393.5 | Diff=  -9.0 | Error= -2.3% 🟢 GOOD
#   Test_Days_30-34          : Pred= 413.0 | Actual= 386.6 | Diff= -26.4 | Error= -6.8% 🟡 MODERATE
#   Test_Days_45-49          : Pred= 408.4 | Actual= 373.0 | Diff= -35.4 | Error= -9.5% 🟡 MODERATE
#   Test_Days_60-64          : Pred= 436.5 | Actual= 446.8 | Diff= +10.4 | Error= +2.3% 🟢 GOOD
#   Test_Days_75-79          : Pred= 453.7 | Actual= 464.7 | Diff= +11.0 | Error= +2.4% 🟢 GOOD
#
# 📊 LOW ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred= 410.7 | Actual= 404.9 | Diff=  -5.7 | Error= -1.4% 🟢 GOOD
#   Last_5_Days              : Pred= 441.3 | Actual= 474.6 | Diff= +33.4 | Error= +7.0% 🟡 MODERATE
#   Test_Days_15-19          : Pred= 393.6 | Actual= 383.5 | Diff= -10.1 | Error= -2.6% 🟢 GOOD
#   Test_Days_30-34          : Pred= 405.5 | Actual= 378.0 | Diff= -27.5 | Error= -7.3% 🟡 MODERATE
#   Test_Days_45-49          : Pred= 403.0 | Actual= 364.0 | Diff= -39.0 | Error=-10.7% 🟠 HIGH
#   Test_Days_60-64          : Pred= 431.4 | Actual= 440.2 | Diff=  +8.8 | Error= +2.0% 🟢 GOOD
#   Test_Days_75-79          : Pred= 443.2 | Actual= 460.1 | Diff= +16.8 | Error= +3.7% 🟢 GOOD
#
# 📊 OPEN ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred= 414.2 | Actual= 406.4 | Diff=  -7.8 | Error= -1.9% 🟢 GOOD
#   Last_5_Days              : Pred= 450.4 | Actual= 477.4 | Diff= +27.1 | Error= +5.7% 🟡 MODERATE
#   Test_Days_15-19          : Pred= 399.5 | Actual= 387.4 | Diff= -12.1 | Error= -3.1% 🟢 GOOD
#   Test_Days_30-34          : Pred= 410.1 | Actual= 383.4 | Diff= -26.8 | Error= -7.0% 🟡 MODERATE
#   Test_Days_45-49          : Pred= 404.6 | Actual= 370.7 | Diff= -34.0 | Error= -9.2% 🟡 MODERATE
#   Test_Days_60-64          : Pred= 433.9 | Actual= 443.1 | Diff=  +9.2 | Error= +2.1% 🟢 GOOD
#   Test_Days_75-79          : Pred= 450.5 | Actual= 461.5 | Diff= +10.9 | Error= +2.4% 🟢 GOOD
#
# 📊 RSI ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred=  42.1 | Actual=  40.0 | Diff=  -2.2 | Error= -5.5% 🟡 MODERATE
#   Last_5_Days              : Pred=  62.0 | Actual=  72.1 | Diff= +10.1 | Error=+14.0% 🟠 HIGH
#   Test_Days_15-19          : Pred=  41.3 | Actual=  38.5 | Diff=  -2.8 | Error= -7.3% 🟡 MODERATE
#   Test_Days_30-34          : Pred=  54.2 | Actual=  41.5 | Diff= -12.7 | Error=-30.7% 🔴 SEVERE
#   Test_Days_45-49          : Pred=  55.0 | Actual=  42.8 | Diff= -12.2 | Error=-28.6% 🔴 SEVERE
#   Test_Days_60-64          : Pred=  69.7 | Actual=  74.1 | Diff=  +4.3 | Error= +5.9% 🟡 MODERATE
#   Test_Days_75-79          : Pred=  62.4 | Actual=  71.5 | Diff=  +9.0 | Error=+12.7% 🟠 HIGH
#
# 📊 OBV ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred=485416829.1 | Actual=429544180.0 | Diff=-55872649.1 | Error=-13.0% 🟠 HIGH
#   Last_5_Days              : Pred=573996530.4 | Actual=717486480.0 | Diff=+143489949.6 | Error=+20.0% 🔴 SEVERE
#   Test_Days_15-19          : Pred=457150787.1 | Actual=425208360.0 | Diff=-31942427.1 | Error= -7.5% 🟡 MODERATE
#   Test_Days_30-34          : Pred=552108550.0 | Actual=492014960.0 | Diff=-60093590.0 | Error=-12.2% 🟠 HIGH
#   Test_Days_45-49          : Pred=357933675.2 | Actual=259221260.0 | Diff=-98712415.2 | Error=-38.1% 🔴 SEVERE
#   Test_Days_60-64          : Pred=494010001.6 | Actual=512897740.0 | Diff=+18887738.4 | Error= +3.7% 🟢 GOOD
#   Test_Days_75-79          : Pred=559532486.8 | Actual=645576500.0 | Diff=+86044013.2 | Error=+13.3% 🟠 HIGH
#
# 📊 VOLUME ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred=21791026.4 | Actual=21067120.0 | Diff=-723906.4 | Error= -3.4% 🟢 GOOD
#   Last_5_Days              : Pred=28878985.8 | Actual=20569980.0 | Diff=-8309005.8 | Error=-40.4% 🔴 SEVERE
#   Test_Days_15-19          : Pred=29283309.7 | Actual=26398420.0 | Diff=-2884889.7 | Error=-10.9% 🟠 HIGH
#   Test_Days_30-34          : Pred=19345351.0 | Actual=21276280.0 | Diff=+1930929.0 | Error= +9.1% 🟡 MODERATE
#   Test_Days_45-49          : Pred=23304233.0 | Actual=20749860.0 | Diff=-2554373.0 | Error=-12.3% 🟠 HIGH
#   Test_Days_60-64          : Pred=24300837.4 | Actual=21031800.0 | Diff=-3269037.4 | Error=-15.5% 🔴 SEVERE
#   Test_Days_75-79          : Pred=24269317.9 | Actual=20287040.0 | Diff=-3982277.9 | Error=-19.6% 🔴 SEVERE
#
# 📊 SMA_50 ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred= 429.1 | Actual= 428.3 | Diff=  -0.8 | Error= -0.2% 🟢 GOOD
#   Last_5_Days              : Pred= 427.1 | Actual= 429.9 | Diff=  +2.8 | Error= +0.6% 🟢 GOOD
#   Test_Days_15-19          : Pred= 410.6 | Actual= 416.0 | Diff=  +5.4 | Error= +1.3% 🟢 GOOD
#   Test_Days_30-34          : Pred= 387.9 | Actual= 404.6 | Diff= +16.7 | Error= +4.1% 🟢 GOOD
#   Test_Days_45-49          : Pred= 381.0 | Actual= 389.0 | Diff=  +8.0 | Error= +2.1% 🟢 GOOD
#   Test_Days_60-64          : Pred= 386.3 | Actual= 390.9 | Diff=  +4.6 | Error= +1.2% 🟢 GOOD
#   Test_Days_75-79          : Pred= 412.7 | Actual= 411.5 | Diff=  -1.2 | Error= -0.3% 🟢 GOOD
#
# 📊 DOW_JONES ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred=44690.6 | Actual=44555.2 | Diff=-135.3 | Error= -0.3% 🟢 GOOD
#   Last_5_Days              : Pred=42418.8 | Actual=42261.4 | Diff=-157.3 | Error= -0.4% 🟢 GOOD
#   Test_Days_15-19          : Pred=42977.1 | Actual=42346.5 | Diff=-630.6 | Error= -1.5% 🟢 GOOD
#   Test_Days_30-34          : Pred=43387.6 | Actual=42066.0 | Diff=-1321.6 | Error= -3.1% 🟢 GOOD
#   Test_Days_45-49          : Pred=42148.5 | Actual=39155.1 | Diff=-2993.4 | Error= -7.6% 🟡 MODERATE
#   Test_Days_60-64          : Pred=42582.5 | Actual=41843.9 | Diff=-738.6 | Error= -1.8% 🟢 GOOD
#   Test_Days_75-79          : Pred=42961.9 | Actual=42368.5 | Diff=-593.4 | Error= -1.4% 🟢 GOOD
#
# 📊 NASDAQ ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred=6059.3 | Actual=6095.9 | Diff= +36.7 | Error= +0.6% 🟢 GOOD
#   Last_5_Days              : Pred=5931.3 | Actual=5988.3 | Diff= +57.0 | Error= +1.0% 🟢 GOOD
#   Test_Days_15-19          : Pred=5871.6 | Actual=5707.6 | Diff=-164.0 | Error= -2.9% 🟢 GOOD
#   Test_Days_30-34          : Pred=5795.2 | Actual=5646.3 | Diff=-149.0 | Error= -2.6% 🟢 GOOD
#   Test_Days_45-49          : Pred=5637.4 | Actual=5276.0 | Diff=-361.4 | Error= -6.8% 🟡 MODERATE
#   Test_Days_60-64          : Pred=5783.5 | Actual=5789.4 | Diff=  +5.9 | Error= +0.1% 🟢 GOOD
#   Test_Days_75-79          : Pred=5961.7 | Actual=5945.6 | Diff= -16.0 | Error= -0.3% 🟢 GOOD
#
# 📊 S&P_500 ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred= 235.9 | Actual= 238.3 | Diff=  +2.3 | Error= +1.0% 🟢 GOOD
#   Last_5_Days              : Pred= 235.0 | Actual= 241.1 | Diff=  +6.1 | Error= +2.5% 🟢 GOOD
#   Test_Days_15-19          : Pred= 221.6 | Actual= 214.3 | Diff=  -7.4 | Error= -3.4% 🟢 GOOD
#   Test_Days_30-34          : Pred= 226.3 | Actual= 209.2 | Diff= -17.2 | Error= -8.2% 🟡 MODERATE
#   Test_Days_45-49          : Pred= 213.6 | Actual= 193.0 | Diff= -20.6 | Error=-10.7% 🟠 HIGH
#   Test_Days_60-64          : Pred= 228.3 | Actual= 226.0 | Diff=  -2.3 | Error= -1.0% 🟢 GOOD
#   Test_Days_75-79          : Pred= 236.8 | Actual= 234.6 | Diff=  -2.2 | Error= -0.9% 🟢 GOOD
#
# 📊 VIX ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred=19722.4 | Actual=19861.5 | Diff=+139.1 | Error= +0.7% 🟢 GOOD
#   Last_5_Days              : Pred=19677.8 | Actual=19524.6 | Diff=-153.2 | Error= -0.8% 🟢 GOOD
#   Test_Days_15-19          : Pred=19039.7 | Actual=17944.5 | Diff=-1095.2 | Error= -6.1% 🟡 MODERATE
#   Test_Days_30-34          : Pred=19031.0 | Actual=17555.0 | Diff=-1476.0 | Error= -8.4% 🟡 MODERATE
#   Test_Days_45-49          : Pred=17441.6 | Actual=16294.6 | Diff=-1147.0 | Error= -7.0% 🟡 MODERATE
#   Test_Days_60-64          : Pred=19161.0 | Actual=18544.5 | Diff=-616.5 | Error= -3.3% 🟢 GOOD
#   Test_Days_75-79          : Pred=19675.6 | Actual=19302.9 | Diff=-372.7 | Error= -1.9% 🟢 GOOD
#
# 📊 TREASURY_3M ANALYSIS:
# Period-wise Analysis:
#   First_5_Test_Days        : Pred=   4.2 | Actual=   4.2 | Diff=  -0.0 | Error= -0.4% 🟢 GOOD
#   Last_5_Days              : Pred=   4.2 | Actual=   4.2 | Diff=  +0.0 | Error= +0.1% 🟢 GOOD
#   Test_Days_15-19          : Pred=   4.3 | Actual=   4.2 | Diff=  -0.1 | Error= -1.8% 🟢 GOOD
#   Test_Days_30-34          : Pred=   4.3 | Actual=   4.2 | Diff=  -0.1 | Error= -1.9% 🟢 GOOD
#   Test_Days_45-49          : Pred=   4.4 | Actual=   4.2 | Diff=  -0.1 | Error= -3.5% 🟢 GOOD
#   Test_Days_60-64          : Pred=   4.3 | Actual=   4.3 | Diff=  -0.0 | Error= -0.6% 🟢 GOOD
#   Test_Days_75-79          : Pred=   4.2 | Actual=   4.2 | Diff=  +0.0 | Error= +0.3% 🟢 GOOD
# ================================================================================
# Diagnostic analysis complete
# ================================================================================

# %%
# Step 5: Create Future Prediction Data
print("Step 5: Creating future prediction data...")
future_data = create_future_prediction_data(
    df, df_lagged, models, scalers,
    predictable_features, forward_filled_features, lag_periods, prediction_horizon
)
print(f"   • Future predictions: {len(future_data)}")
# Out:
# Step 5: Creating future prediction data...
# Generating future prediction database...
# Future start index: 445 (out of 448 total)
# Predicting features for next 5 days beyond the dataset
# Predicting day 1/5...
# Predicting day 2/5...
# Predicting day 3/5...
# Predicting day 4/5...
# Predicting day 5/5...
#
# Adding forward-filled features from last available day...
# Forward-filled features added: ['Fed_Funds_Rate', 'CPI', 'PPI', 'Unemployment_Rate', 'Industrial_Production', 'Consumer_Sentiment', 'Housing_Starts', 'CPI_YoY_Change', 'PPI_YoY_Change', 'Yield_Curve_Spread', 'Fed_10Y_Spread', 'Treasury_10Y_DoD', 'Treasury_3M_DoD']
# Updated shape: (5, 33)
#
# Future prediction database shape: (5, 34)
#
# Sample of future predictions:
#       Dow_Jones        High         Low       NASDAQ        Open     S&P_500  \
# 0  42386.365221  454.116652  439.958096  5921.096241  452.205844  233.421314
# 1  42336.744060  450.609565  440.636304  5870.751604  448.351474  230.255856
# 2  42417.733837  447.490311  434.796700  5875.765306  441.333488  229.795431
# 3  42553.537977  444.815344  434.821910  5903.520698  441.066885  229.934697
# 4  42732.224660  440.840115  429.864188  5894.404123  434.372192  230.791683
#
#    Sector_Technology  Treasury_10Y  Treasury_3M           VIX  ...  \
# 0          21.288987      4.459382     4.228915  19511.230820  ...
# 1          22.668122      4.507075     4.228666  19572.974899  ...
# 2          23.004452      4.548861     4.227846  19571.318074  ...
# 3          22.850686      4.571904     4.227846  19610.602155  ...
# 4          22.845187      4.579800     4.216071  19641.356247  ...
#
#    Industrial_Production  Consumer_Sentiment  Housing_Starts  CPI_YoY_Change  \
# 0               103.5948                52.2          1256.0        2.375934
# 1               103.5948                52.2          1256.0        2.375934
# 2               103.5948                52.2          1256.0        2.375934
# 3               103.5948                52.2          1256.0        2.375934
# 4               103.5948                52.2          1256.0        2.375934
#
#    PPI_YoY_Change  Yield_Curve_Spread  Fed_10Y_Spread  Treasury_10Y_DoD  \
# 0        1.457035                0.15            0.05               0.0
# 1        1.457035                0.15            0.05               0.0
# 2        1.457035                0.15            0.05               0.0
# 3        1.457035                0.15            0.05               0.0
# 4        1.457035                0.15            0.05               0.0
#
#    Treasury_3M_DoD Close
# 0              0.0   NaN
# 1              0.0   NaN
# 2              0.0   NaN
# 3              0.0   NaN
# 4              0.0   NaN
#
# [5 rows x 34 columns]
#    • Future predictions: 5

# %%
# Step 6: Save Results
print("Step 6: Saving results...")
import os
output_dir = f'../data/predicted_features/{ticker}'
os.makedirs(output_dir, exist_ok=True)

validation_data.to_csv(f'{output_dir}/historical_validation_features_combined.csv', index=False)
future_data.to_csv(f'{output_dir}/future_prediction_features.csv', index=False)

print("✅ Feature Forecasting Completed Successfully!")
print(f"📂 Results saved to: {output_dir}/")
# Out:
# Step 6: Saving results...
# ✅ Feature Forecasting Completed Successfully!
# 📂 Results saved to: ../data/predicted_features/MSFT/
